# %%
import torch
import time
from torch import nn, optim
from torch.optim import lr_scheduler
from utils import load_data, weight_initialization
from metrics import compute_accuracy
from train import hyperparam_opt
from models import *

# %%
model = MLP(mode='dropout')
HP_res = hyperparam_opt(model)
# Out:
# Parameters: 53105
# Hyperparameters: eta=0.01, decay=0.1, alpha=0
#
# Trial 1/3... Training time: 3.39 s
# Trial 2/3... Training time: 3.35 s
# Trial 3/3... Training time: 3.34 s
# Train accuracy - mean: 0.7677, std: 0.0165, median: 0.7630
# Test accuracy - mean: 0.7270, std: 0.0087, median: 0.7320
#
# Hyperparameters: eta=0.01, decay=0.01, alpha=0
#
# Trial 1/3... Training time: 3.39 s
# Trial 2/3... Training time: 3.36 s
# Trial 3/3... Training time: 3.41 s
# Train accuracy - mean: 0.8927, std: 0.0305, median: 0.8910
# Test accuracy - mean: 0.7683, std: 0.0422, median: 0.7820
#
# Hyperparameters: eta=0.01, decay=0.001, alpha=0
#
# Trial 1/3... Training time: 3.30 s
# Trial 2/3... Training time: 3.42 s
# Trial 3/3... Training time: 3.32 s
# Train accuracy - mean: 0.9287, std: 0.0570, median: 0.9570
# Test accuracy - mean: 0.7687, std: 0.0305, median: 0.7690
#
# Hyperparameters: eta=0.01, decay=0.0001, alpha=0
#
# Trial 1/3... Training time: 3.43 s
# Trial 2/3... Training time: 3.35 s
# Trial 3/3... Training time: 3.39 s
# Train accuracy - mean: 0.8320, std: 0.2436, median: 0.9620
# Test accuracy - mean: 0.7170, std: 0.1365, median: 0.7700
#
# Hyperparameters: eta=0.01, decay=1e-05, alpha=0
#
# Trial 1/3... Training time: 3.35 s
# Trial 2/3... Training time: 3.54 s
# Trial 3/3... Training time: 3.82 s
# Train accuracy - mean: 0.9630, std: 0.0225, median: 0.9640
# Test accuracy - mean: 0.7767, std: 0.0354, median: 0.7930
#
# Hyperparameters: eta=0.005, decay=0.1, alpha=0
#
# Trial 1/3... Training time: 3.90 s
# Trial 2/3... Training time: 3.56 s
# Trial 3/3... Training time: 3.63 s
# Train accuracy - mean: 0.7693, std: 0.0258, median: 0.7620
# Test accuracy - mean: 0.7270, std: 0.0098, median: 0.7240
#
# Hyperparameters: eta=0.005, decay=0.01, alpha=0
#
# Trial 1/3... Training time: 3.44 s
# Trial 2/3... Training time: 3.57 s
# Trial 3/3... Training time: 3.41 s
# Train accuracy - mean: 0.9663, std: 0.0163, median: 0.9630
# Test accuracy - mean: 0.7897, std: 0.0237, median: 0.7860
#
# Hyperparameters: eta=0.005, decay=0.001, alpha=0
#
# Trial 1/3... Training time: 3.61 s
# Trial 2/3... Training time: 3.60 s
# Trial 3/3... Training time: 3.30 s
# Train accuracy - mean: 0.9827, std: 0.0174, median: 0.9890
# Test accuracy - mean: 0.7927, std: 0.0303, median: 0.7880
#
# Hyperparameters: eta=0.005, decay=0.0001, alpha=0
#
# Trial 1/3... Training time: 3.81 s
# Trial 2/3... Training time: 3.48 s
# Trial 3/3... Training time: 5.18 s
# Train accuracy - mean: 0.9900, std: 0.0052, median: 0.9930
# Test accuracy - mean: 0.7930, std: 0.0235, median: 0.8040
#
# Hyperparameters: eta=0.005, decay=1e-05, alpha=0
#
# Trial 1/3... Training time: 4.97 s
# Trial 2/3... Training time: 4.69 s
# Trial 3/3... Training time: 4.85 s
# Train accuracy - mean: 0.9867, std: 0.0081, median: 0.9820
# Test accuracy - mean: 0.8007, std: 0.0237, median: 0.7970
#
# Hyperparameters: eta=0.001, decay=0.1, alpha=0
#
# Trial 1/3... Training time: 4.51 s
# Trial 2/3... Training time: 3.91 s
